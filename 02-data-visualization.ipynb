# %% [markdown]
# # 02 — Exploratory Data Analysis & Visualization
#
# **Purpose:** Explore seasonality patterns in passenger boarding data across 2015, 2018, and 2020.
#
# **Key plots:** Hourly seasonality (bimodal rush-hour pattern), daily/weekly cycles,
# monthly trends, and top bus line rankings by ridership volume.

# %% [markdown]
# ## Evaluating complete dataset (March 2020 - December 2020/Jan 1 2021)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

transformar_features = False
data_2020 = pd.read_csv('./data_input_zerofill_2020.csv', delimiter=';')
data_2018 = pd.read_csv('./data_input_zerofill_2018.csv')
data_2015 = pd.read_csv('./data_input_zerofill_2015.csv', delimiter=';')

busline_filter = 41
# data_model = data.loc[data['linha'] == busline_filter]
# display(data_model)

# %%
data_2020
# Out:
#          linha            data_hora  validations_per_hour  d_semana  hour_sin  \
# 0            1  2020-03-01 00:00:00                     0         6  0.000000
# 1            1  2020-03-01 01:00:00                     0         6  0.269797
# 2            1  2020-03-01 02:00:00                     0         6  0.519584
# 3            1  2020-03-01 03:00:00                     0         6  0.730836
# 4            1  2020-03-01 04:00:00                     0         6  0.887885
# ...        ...                  ...                   ...       ...       ...
# 1604349    999  2020-12-01 08:00:00                    12         1  0.816970
# 1604350    999  2020-12-01 09:00:00                     1         1  0.631088
# 1604351    999  2020-12-01 10:00:00                     1         1  0.398401
# 1604352    999  2020-12-01 11:00:00                     5         1  0.136167
# 1604353    999  2020-12-01 12:00:00                     3         1 -0.136167
#
#          hour_cos  hora  d_mes  d_ano  mes  semana_do_mes
# 0        1.000000     0      1     61    3              1
# 1        0.962917     1      1     61    3              1
# 2        0.854419     2      1     61    3              1
# 3        0.682553     3      1     61    3              1
# 4        0.460065     4      1     61    3              1
# ...           ...   ...    ...    ...  ...            ...
# 1604349 -0.576680     8      1    336   12              0
# 1604350 -0.775711     9      1    336   12              0
# 1604351 -0.917211    10      1    336   12              0
# 1604352 -0.990686    11      1    336   12              0
# 1604353 -0.990686    12      1    336   12              0
#
# [1604354 rows x 11 columns]

# %%
data_2018
# Out:
#          linha            data_hora  validations_per_hour  d_semana  \
# 0            1  2020-01-11 02:00:00                     0         5
# 1            1  2020-01-31 03:00:00                     0         4
# 2            1  2020-02-02 03:00:00                     0         6
# 3            1  2020-02-19 02:00:00                     0         2
# 4            1  2020-02-20 02:00:00                     0         3
# ...        ...                  ...                   ...       ...
# 1229961    999  2018-07-02 21:00:00                     5         0
# 1229962    999  2018-07-02 22:00:00                     8         0
# 1229963    999  2018-07-02 23:00:00                     1         0
# 1229964    999  2018-07-30 20:00:00                     2         0
# 1229965    999  2018-07-30 22:00:00                     1         0
#
#              hour_sin  hour_cos  hora  d_mes  d_ano  mes  semana_do_mes
# 0        5.195840e-01  0.854419     2     11     11    1              2
# 1        7.308360e-01  0.682553     3     31     31    1              5
# 2        7.308360e-01  0.682553     3      2     33    2              1
# 3        5.195840e-01  0.854419     2     19     50    2              4
# 4        5.195840e-01  0.854419     2     20     51    2              4
# ...               ...       ...   ...    ...    ...  ...            ...
# 1229961 -5.195840e-01  0.854419    21      2    183    7              1
# 1229962 -2.697968e-01  0.962917    22      2    183    7              1
# 1229963 -2.449294e-16  1.000000    23      2    183    7              1
# 1229964 -7.308360e-01  0.682553    20     30    211    7              5
# 1229965 -2.697968e-01  0.962917    22     30    211    7              5
#
# [1229966 rows x 11 columns]

# %%
data_2015
# Out:
#          linha            data_hora  validations_per_hour  d_semana  hour_sin  \
# 0            1  2015-01-15 02:00:00                     0         3  0.519584
# 1            1  2015-01-25 02:00:00                     0         6  0.519584
# 2            1  2015-01-25 06:00:00                     0         6  0.997669
# 3            1  2015-01-25 07:00:00                     0         6  0.942261
# 4            1  2015-01-25 08:00:00                     0         6  0.816970
# ...        ...                  ...                   ...       ...       ...
# 2081985    999  2015-12-05 09:00:00                    18         5  0.631088
# 2081986    999  2015-12-05 10:00:00                    64         5  0.398401
# 2081987    999  2015-12-05 11:00:00                     8         5  0.136167
# 2081988    999  2015-12-05 12:00:00                    43         5 -0.136167
# 2081989    999  2015-12-31 07:00:00                     1         3  0.942261
#
#          hour_cos  hora  d_mes  d_ano  mes  semana_do_mes
# 0        0.854419     2     15     15    1              3
# 1        0.854419     2     25     25    1              4
# 2       -0.068242     6     25     25    1              4
# 3       -0.334880     7     25     25    1              4
# 4       -0.576680     8     25     25    1              4
# ...           ...   ...    ...    ...  ...            ...
# 2081985 -0.775711     9      5    339   12              0
# 2081986 -0.917211    10      5    339   12              0
# 2081987 -0.990686    11      5    339   12              0
# 2081988 -0.990686    12      5    339   12              0
# 2081989 -0.334880     7     31    365   12              4
#
# [2081990 rows x 11 columns]

# %%
top100_linhas_2020 = data_2020.groupby(data_2020.linha).sum().reset_index().sort_values('validations_per_hour', ascending=False).index[:100].to_list()
print(top100_linhas_2020)

top100_linhas_2018 = data_2018.groupby(data_2018.linha).sum().reset_index().sort_values('validations_per_hour', ascending=False).index[:100].to_list()
print(top100_linhas_2018)

top100_linhas_2015 = data_2015.groupby(data_2015.linha).sum().reset_index().sort_values('validations_per_hour', ascending=False).index[:50].to_list()
print(top100_linhas_2015)
# Out:
# [1, 38, 47, 48, 39, 72, 333, 42, 7, 0, 41, 367, 23, 341, 35, 307, 4, 337, 70, 199, 27, 25, 73, 46, 339, 26, 327, 88, 354, 226, 6, 340, 245, 71, 318, 374, 24, 29, 250, 28, 76, 69, 334, 62, 261, 66, 257, 302, 21, 137, 49, 135, 162, 330, 204, 5, 94, 348, 95, 12, 382, 258, 349, 231, 282, 264, 102, 168, 148, 246, 128, 319, 332, 3, 263, 190, 67, 130, 82, 75, 78, 103, 40, 215, 335, 356, 64, 180, 217, 127, 80, 221, 164, 361, 56, 219, 100, 195, 158, 123]
# [1, 37, 38, 41, 46, 20, 71, 307, 47, 69, 70, 40, 350, 26, 45, 34, 24, 286, 72, 0, 301, 87, 22, 181, 25, 122, 317, 23, 68, 61, 81, 315, 28, 95, 27, 94, 313, 225, 75, 65, 4, 185, 355, 120, 230, 7, 340, 306, 9, 240, 102, 8, 281, 293, 170, 168, 226, 341, 12, 77, 308, 83, 48, 74, 237, 66, 361, 304, 224, 109, 172, 113, 103, 100, 357, 334, 316, 335, 342, 55, 115, 39, 143, 221, 149, 233, 336, 112, 262, 354, 202, 162, 346, 242, 67, 145, 196, 352, 243, 80]
# [37, 41, 1, 38, 47, 48, 20, 72, 22, 40, 70, 71, 26, 24, 73, 283, 46, 25, 69, 34, 303, 0, 88, 183, 82, 345, 96, 297, 23, 302, 95, 27, 28, 278, 9, 123, 226, 66, 76, 350, 187, 309, 8, 62, 240, 104, 122, 237, 103, 4]

# %%
print('Number of Bus Lines 2020: ', len(data_2020.linha.unique()))
print('Number of Bus Lines 2018: ', len(data_2018.linha.unique()))
print('Number of Bus Lines 2015: ', len(data_2015.linha.unique()))
# data
# Out:
# Quantidade de Linhas de Onibus 2020:  404
# Quantidade de Linhas de Onibus 2018:  390
# Quantidade de Linhas de Onibus 2015:  396

# %% [markdown]
# ## Annual / Daily Seasonality

# %%
import matplotlib.ticker as ticker

plt.figure(figsize=(20,5))
plt.title("Day-of-Year Seasonality")
sns.set_theme(style="whitegrid")
plt.ticklabel_format(style = 'plain')
ax = sns.lineplot(x="d_ano", y="validations_per_hour", data=data_2015.groupby(['d_ano']).sum().reset_index(), color='salmon')
ax.xaxis.set_major_locator(ticker.MultipleLocator(30))
ax.xaxis.set_major_formatter(ticker.ScalarFormatter())
plt.xlabel('Meses')
plt.ylabel('Count de Validacoes')
plt.savefig('./images/sazonalidade_d_ano.pdf')
plt.show()

# %% [markdown]
# ## Monthly Validation Counts

# %%
plt.figure(figsize=(15,5))
plt.title("Monthly Seasonality")
sns.set_theme(style="whitegrid")
plt.ticklabel_format(style = 'plain')
sns.barplot(x="mes", y="validations_per_hour", data=data_2015.groupby(['mes']).sum().reset_index(), color='salmon', saturation=.5)
plt.xlabel('Meses')
plt.ylabel('Count de Validacoes')
plt.savefig('./images/sazonalidade_mensal.pdf')
plt.show()

# %%
plt.rc('axes', linewidth=2, labelpad=5)
plt.rc('text', usetex=True)
plt.rc('font', family='serif', serif='Computer Modern', size=42)
sns.set(font_scale = 2)
sns.set_theme(style="whitegrid")
plt.rc('axes', linewidth=2, labelpad=5)

plt.figure(figsize=(15,8))
plt.title("Daily Seasonality (Monthly)", fontsize=21)
plt.ticklabel_format(style = 'plain')
sns.barplot(x="d_mes", y="validations_per_hour", data=data_2015.groupby(['d_mes']).sum().reset_index(), color="salmon", saturation=.5, ci=None)
plt.xlabel('Hora', fontsize=21)
plt.ylabel('Count de embarques', fontsize=21)
plt.xticks(fontsize=21)
plt.yticks(fontsize=21)
plt.legend(fontsize=21)
plt.savefig('./images/sazonalidade_dia_mes.pdf')
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
data_2015.groupby(data_2015.linha).sum().sort_values('validations_per_hour', ascending=False).reset_index()[:50]
# Out:
#     linha  validations_per_hour  d_semana    hour_sin     hour_cos    hora  \
# 0      41               5024650     26848   -5.207225   385.917829  102377
# 1      45               4891215     26737   -4.576432   362.587054  102380
# 2       3               4863088     28394  115.643758   614.258481  103542
# 3      42               4780266     26734   -4.667631   363.843663  102379
# 4      51               4475808     26847   -2.325379   389.769497  102389
# 5      52               4271791     26881   -0.304325   404.496817  102401
# 6      24               4183870     26813   -9.121300   394.000661  102360
# 7      76               3948406     26817   -3.808600   376.962376  102384
# 8      26               3865226     26784   -9.121300   369.000661  102360
# 9      44               3865069     26686   -9.121300   351.000661  102360
# 10     74               3799898     26685   -9.121300   351.000661  102360
# 11     75               3664901     20537 -888.377319 -1058.962416   96184
# 12     30               3458985     26700   -6.713198   353.960616  102370
# 13     28               3425357     26703   -7.345530   354.920791  102368
# 14     77               3361117     26740   -8.397770   361.783877  102363
# 15    660               3350852     17332 -387.364001 -1168.817262   83052
# 16     50               3239880     14381 -456.975454  -909.826513   76879
# 17     29               3044702     26704  -10.897071   355.080531  102352
# 18     73               3016758     14868 -547.469115  -754.087763   80034
# 19     38               3008505     26694  -11.784956   353.620466  102348
# 20    712               2938901     20338 -568.024072 -1044.493959   91965
# 21      1               2928838     28783  269.402936   760.318290  104418
# 22     92               2915625     13967 -701.712371 -1054.546970   74875
# 23    355               2909193     26685   -8.233415   350.460726  102364
# 24     86               2708745     16004 -460.924340  -456.364365   80425
# 25    855               2588860     20577 -871.732889 -1071.503664   96292
# 26    101               2553982     27457  -21.976879   224.021076  106221
# 27    703               2342572     17554 -537.872595 -1552.409220   81187
# 28     27               2325214     20965 -806.624752  -980.399383   96582
# 29    711               2268045     26732   -9.121300   361.000661  102360
# 30     99               2255826     14919 -634.527166  -685.017573   79669
# 31     31               2238713     26686   -9.121300   351.000661  102360
# 32     32               2217522     26686   -9.121300   351.000661  102360
# 33    650               2206522     20258 -865.352094 -1142.342246   94612
# 34     12               2201762     21180 -658.085061  -966.248944   96976
# 35    222               2194812     19860 -812.492828 -1349.200209   89451
# 36    406               2176192     26680   -9.121300   350.000661  102360
# 37     70               2151377     26689   -9.121300   352.000661  102360
# 38     80               2087335     20588 -868.890636 -1070.829777   96074
# 39    906               2083237     26688   -8.233415   350.460726  102364
# 40    360               2068555     21356 -571.627685 -1033.001681   94838
# 41    754               2026764     30022  -67.872166  -249.213502  119178
# 42     11               2012990     20938 -682.170710 -1021.490779   95948
# 43     66               1938315     20771 -836.217480 -1046.101062   96452
# 44    603               1909963     20715 -672.049914 -1027.732421   95811
# 45    115               1890986     21159 -611.863422 -1005.468792   95874
# 46    220               1884965     26685  -10.009185   351.540596  102356
# 47    600               1874867     21058 -632.095079 -1018.029495   95715
# 48    114               1871554     26680   -9.121300   350.000661  102360
# 49      6               1863284     26951   29.305781   386.535248  102701
#
#      d_mes    d_ano    mes  semana_do_mes
# 0   139470  1628786  58119          20801
# 1   139212  1626996  58045          20782
# 2   145169  1705823  60875          20593
# 3   139125  1626063  58018          20762
# 4   139724  1631133  58193          20810
# 5   139819  1633590  58288          20821
# 6   139585  1631235  58202          20866
# 7   139401  1629148  58125          20802
# 8   139174  1627231  58058          20804
# 9   138951  1624440  57955          21066
# 10  138940  1624460  57956          21045
# 11  107482  1262254  45024          15197
# 12  139054  1625237  57982          21061
# 13  139043  1625622  57996          20954
# 14  139035  1625495  57998          21065
# 15  100552  1213403  43117          14423
# 16   91589  1070273  38127          13343
# 17  138971  1624762  57968          20990
# 18   92841  1085360  38679          13493
# 19  138960  1624600  57961          20977
# 20  107731  1304421  46404          15177
# 21  150120  1718492  61396          21397
# 22   86943  1016385  36207          12613
# 23  138950  1624348  57952          21019
# 24   98718  1149556  40957          14309
# 25  107426  1260612  44973          15181
# 26  144436  1673038  59697          21962
# 27   99491  1198453  42588          14188
# 28  109634  1287216  45908          15486
# 29  139068  1626096  58016          20832
# 30   93459  1094411  38976          13573
# 31  138951  1624440  57955          21078
# 32  138951  1624440  57955          21094
# 33  106426  1248355  44536          15059
# 34  111044  1300040  46390          15706
# 35  103579  1220598  43536          14637
# 36  138932  1624240  57948          21147
# 37  138961  1624693  57964          21036
# 38  107514  1261858  45013          15191
# 39  138933  1624241  57949          21088
# 40  110812  1301514  46433          15648
# 41  159874  1869288  66754          24902
# 42  109927  1294330  46167          15550
# 43  108157  1268790  45266          15276
# 44  110012  1291241  46064          15599
# 45  111035  1303182  46482          15701
# 46  138951  1624410  57954          20959
# 47  110518  1294218  46181          15638
# 48  138932  1624240  57948          21138
# 49  140207  1644668  58669          19966

# %%
d = data_2015.groupby(data_2015.linha).sum().reset_index()[:50]
plt.rc('patch',linewidth=2)
plt.rc('axes', linewidth=2, labelpad=5)
plt.rc('xtick.minor', size=8, width=4)
plt.rc('ytick.minor', size=8, width=4)
plt.figure(figsize=(20,10))
plt.ticklabel_format(style = 'plain')
plt.title("Comparativo de linhas", fontsize=32)
values = np.array(d.validations_per_hour)
clrs = ['blue' if (x < max(values)) else 'red' for x in values ]
sns.barplot(x='linha', y='validations_per_hour', data=d, palette=clrs, saturation=.3, ci=None)
plt.xlabel('Linhas', fontsize=32)
plt.xticks(fontsize=20)
plt.yticks(fontsize=24)
plt.ylabel('Count de embarques', fontsize=32)
plt.savefig('./images/comparativo_linhas.pdf')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.ticklabel_format(style = 'plain')
plt.title("Daily Seasonality (Weekly)")
sns.barplot(x='d_semana', y='validations_per_hour', data=data_2015.groupby(['d_semana']).sum().reset_index(), color="blue", saturation=.3, ci=None)
plt.xlabel('Time')
plt.ylabel('Count')
plt.savefig('./images/sazonalidade_dia_semana.pdf')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.ticklabel_format(style = 'plain')
plt.title("Hourly Seasonality")
sns.lineplot(x='hora', y='validations_per_hour', data=data_2015.groupby(['hora']).sum().reset_index(), color="orange", ci=None)
plt.xlabel('Time')
plt.ylabel('Count')
plt.savefig('./images/hourly_seasonality.pdf')
plt.show()

# %%
plt.rc('axes', linewidth=2, labelpad=5)
plt.rc('text', usetex=True)
plt.rc('font', family='serif', serif='Computer Modern', size=60)
sns.set(font_scale = 3)
plt.figure(figsize=(20,10))
plt.title("Outubro 2015 - Somatório de embarques por hora")
p = sns.barplot(x='hora', y='validations_per_hour', 
    data=data_2015.loc[data_2015.mes == 10].loc[data_2015.linha == 41].groupby([ 'hora']).sum().reset_index(), color="brown", saturation=.3, ci=None)
plt.xlabel('Hora')
plt.ylabel('Count de validações')
plt.savefig('./images/sazonalidade_out_2015.pdf')
plt.show()

# %%
plt.rc('axes', linewidth=2, labelpad=5)
plt.rc('text', usetex=True)
plt.rc('font', family='serif', serif='Computer Modern', size=60)
sns.set(font_scale = 3)
plt.figure(figsize=(20,10))
plt.title("Novembro 2015 - Somatório de embarques por hora")
sns.barplot(x='hora', y='validations_per_hour', data=data_2015.loc[data_2015.mes == 8].loc[data_2015.linha == 41].groupby([ 'hora']).sum().reset_index(), color="darkcyan", saturation=.3, ci=None)
sns.barplot(x='hora', y='validations_per_hour', data=data_2015.loc[data_2015.mes == 9].loc[data_2015.linha == 41].groupby([ 'hora']).sum().reset_index(), color="pink", saturation=.3, ci=None)
sns.barplot(x='hora', y='validations_per_hour', 
    data=data_2015.loc[data_2015.mes == 10].loc[data_2015.linha == 41].groupby([ 'hora']).sum().reset_index(), color="brown", saturation=.3, ci=None)
sns.barplot(x='hora', y='validations_per_hour', data=data_2015.loc[data_2015.mes == 11].loc[data_2015.linha == 41].groupby([ 'hora']).sum().reset_index(), color="blue", saturation=.3, ci=None)
plt.legend(['Agosto', 'Outubro', 'Setembro', 'Novembro'], bbox_to_anchor=(0.2, 0.05), loc=0, borderaxespad=0.,)

plt.xlabel('Hora')
plt.ylabel('Count de validações')
plt.savefig('./images/sazonalidade_nov_2015.pdf')
plt.show()

# %%
colors = ['orange', 'red', 'black', 'green', 'purple', 'olive', 'cyan']

plt.rc('axes', linewidth=2, labelpad=5)
plt.rc('text', usetex=True)
plt.rc('font', family='serif', serif='Computer Modern', size=42)
sns.set(font_scale = 2)
sns.set_theme(style="whitegrid")
plt.rc('axes', linewidth=2, labelpad=5)
plt.figure(figsize=(17,10))

plt.xlabel('Hora', fontsize=32)
plt.ylabel('Count de passageiros', fontsize=32)
plt.title("Hourly Seasonality on Weekdays", fontsize=32)
sns.lineplot(x='hora', y='validations_per_hour', data=data_2015.loc[data_2015.d_semana == 0].groupby([ 'hora']).sum().reset_index(), ci=None, color='orange', label='segunda')
sns.lineplot(x='hora', y='validations_per_hour', data=data_2015.loc[data_2015.d_semana == 1].groupby([ 'hora']).sum().reset_index(), ci=None, color='black', label='terca')
sns.lineplot(x='hora', y='validations_per_hour', data=data_2015.loc[data_2015.d_semana == 2].groupby([ 'hora']).sum().reset_index(), ci=None, color='olive', label='quarta')
sns.lineplot(x='hora', y='validations_per_hour', data=data_2015.loc[data_2015.d_semana == 3].groupby([ 'hora']).sum().reset_index(), ci=None, color='purple', label='quinta')
sns.lineplot(x='hora', y='validations_per_hour', data=data_2015.loc[data_2015.d_semana == 4].groupby([ 'hora']).sum().reset_index(), ci=None, color='red', label='sexta')
plt.xticks(fontsize=21)
plt.yticks(fontsize=21)
plt.legend(fontsize=32)
plt.savefig(f'./images/hourly_seasonality_weekdays.pdf')
plt.show()

# plt.figure(figsize=(17,10))

# plt.xlabel('Hour', fontsize=32)
# plt.ylabel('Passenger count', fontsize=32)
# plt.title("Hourly Seasonality on Weekends", fontsize=32)
# sns.lineplot(x='hora', y='validations_per_hour', data=data_2015.loc[data_2015.d_semana == 5].groupby([ 'hora']).sum().reset_index(), ci=None, color='brown', label='sabado')
# sns.lineplot(x='hora', y='validations_per_hour', data=data_2015.loc[data_2015.d_semana == 6].groupby([ 'hora']).sum().reset_index(), ci=None, color='salmon', label='domingo')
# plt.xticks(fontsize=21)
# plt.yticks(fontsize=21)
# plt.legend(fontsize=32)
# plt.savefig(f'./images/hourly_seasonality_weekends.pdf')
# plt.show()

# %% [markdown]
# ## Bus Line Visualization
#
# ### Ranking (Top 10 / 100)
# Ranking based on comparison of the best-performing models analyzed: (example below for bus line 41)
# - Stacking Regressors
# - RandomForest GridSearched
# - RandomForest Default
# - RandomForest Bagging
# - GradientBoostingRegressor
# - LinearRegression Bagging
# - LinearReg GridSearched
# - LinearReg Default

# %%
# data_m = pd.read_csv('./data_input_zerofill.csv', sep=';', delimiter=';')

# %%
# plt.figure(figsize=(15,5))
# plt.xlabel('Time')
# plt.ylabel('Count')

# plt.title("Bus Line Evaluation")
# sns.lineplot(x='hora', y='validations_per_hour', data=data_m[data_m.linha == 325], ci=None, color='orange', label="325")
# sns.lineplot(x='hora', y='validations_per_hour', data=data_m[data_m.linha == 384], ci=None, color='blue', label="384")
# sns.lineplot(x='hora', y='validations_per_hour', data=data_m[data_m.linha == 332], ci=None, color='red', label="332")
# sns.lineplot(x='hora', y='validations_per_hour', data=data_m[data_m.linha == 619], ci=None, color='green', label="619")
# sns.lineplot(x='hora', y='validations_per_hour', data=data_m[data_m.linha == 641], ci=None, color='yellow', label="641")
# sns.lineplot(x='hora', y='validations_per_hour', data=data_m[data_m.linha == 630], ci=None, color='black', label="630")
# # sns.lineplot(x='hora', y='validations_per_hour', data=data_m[data_m.linha == 41], ci=None, color='brown', label="41")
# plt.legend(loc="upper left")
# plt.show()

# plt.figure(figsize=(15,5))
# plt.xlabel('Time')
# plt.ylabel('Count')

# plt.title("Bus Line Evaluation WITH 041")
# sns.lineplot(x='hora', y='validations_per_hour', data=data_m[data_m.linha == 325], ci=None, color='orange', label="325")
# sns.lineplot(x='hora', y='validations_per_hour', data=data_m[data_m.linha == 384], ci=None, color='blue', label="384")
# sns.lineplot(x='hora', y='validations_per_hour', data=data_m[data_m.linha == 332], ci=None, color='red', label="332")
# sns.lineplot(x='hora', y='validations_per_hour', data=data_m[data_m.linha == 619], ci=None, color='green', label="619")
# sns.lineplot(x='hora', y='validations_per_hour', data=data_m[data_m.linha == 641], ci=None, color='yellow', label="641")
# sns.lineplot(x='hora', y='validations_per_hour', data=data_m[data_m.linha == 630], ci=None, color='black', label="630")
# sns.lineplot(x='hora', y='validations_per_hour', data=data_m[data_m.linha == 41], ci=None, color='brown', label="41")
# plt.legend(loc="upper left")
# plt.show()

# %%
# plt.figure(figsize=(15,5))
# plt.xlabel('Time')
# plt.ylabel('Count')

# plt.title("Bus Line Evaluation WITH 041")
# sns.lineplot(x='hora', y='validations_per_hour', data=data_m[data_m.linha == 325], ci=None, color='orange', label="325")
# sns.lineplot(x='hora', y='validations_per_hour', data=data_m[data_m.linha == 384], ci=None, color='blue', label="384")
# sns.lineplot(x='hora', y='validations_per_hour', data=data_m[data_m.linha == 332], ci=None, color='red', label="332")
# sns.lineplot(x='hora', y='validations_per_hour', data=data_m[data_m.linha == 619], ci=None, color='green', label="619")
# sns.lineplot(x='hora', y='validations_per_hour', data=data_m[data_m.linha == 641], ci=None, color='yellow', label="641")
# sns.lineplot(x='hora', y='validations_per_hour', data=data_m[data_m.linha == 630], ci=None, color='black', label="630")
# sns.lineplot(x='hora', y='validations_per_hour', data=data_m[data_m.linha == 41], ci=None, color='brown', label="41")
# plt.legend(loc="upper left")
# plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
def rand_times(n):
    """Generate n rows of random 24-hour times (seconds past midnight)"""
    rand_seconds = np.random.randint(0, 24, n)
    return pd.DataFrame(data=dict(seconds=rand_seconds))

n_rows = 744

df = rand_times(n_rows)
# sort for the sake of graphing
df = df.sort_values('seconds').reset_index(drop=True)
df.head()

seconds_in_day = 24

df['sin_hora'] = np.sin(2*np.pi*df.seconds/seconds_in_day)
df['cos_hora'] = np.cos(2*np.pi*df.seconds/seconds_in_day)

df.drop('seconds', axis=1, inplace=True)

df.head()
plt.figure(figsize=(10,20))
plt.rc('axes', linewidth=2, labelpad=5)
plt.rc('font', family='serif', serif='Computer Modern', size=32)
sns.set(font_scale = 2)
plt.rc('text', usetex=False)
df.sample(168).plot.scatter('sin_hora','cos_hora').set_aspect('equal');
plt.savefig(f'./images/sin_cos.pdf')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
# plt.rc('axes', linewidth=2, labelpad=5)
# plt.rc('text', usetex=True)
# plt.rc('font', family='serif', serif='Computer Modern', size=60)
# sns.set(font_scale = 3)
df.sin_hora.plot()
plt.savefig(f'./images/sin.pdf')

# %%
# plt.rc('axes', linewidth=2, labelpad=5)
# plt.rc('text', usetex=True)
# plt.rc('font', family='serif', serif='Computer Modern', size=60)
# sns.set(font_scale = 3)
df.cos_hora.plot()
plt.savefig(f'./images/cos.pdf')

# %%
plt.rc('axes', linewidth=2, labelpad=5)
plt.rc('text', usetex=True)
plt.rc('font', family='serif', serif='Computer Modern', size=42)
sns.set(font_scale = 2)
sns.set_theme(style="whitegrid")
plt.rc('axes', linewidth=2, labelpad=5)
plt.figure(figsize=(17,10))

# plt.figure(figsize=(15,5))
plt.xlabel('Hora', fontsize=24)
plt.ylabel('Count', fontsize=24)

plt.title("Weekly Seasonality", fontsize=24)
sns.lineplot(x='hora', y='validations_per_hour', data=data_2015[data_2015.semana_do_mes == 1].groupby([ 'hora']).sum().reset_index(), ci=None, color='orange', label="Semana 1")
sns.lineplot(x='hora', y='validations_per_hour', data=data_2015[data_2015.semana_do_mes == 2].groupby([ 'hora']).sum().reset_index(), ci=None, color='purple', label="Semana 2")
sns.lineplot(x='hora', y='validations_per_hour', data=data_2015[data_2015.semana_do_mes == 3].groupby([ 'hora']).sum().reset_index(), ci=None, color='salmon', label="Semana 3")
sns.lineplot(x='hora', y='validations_per_hour', data=data_2015[data_2015.semana_do_mes == 4].groupby([ 'hora']).sum().reset_index(), ci=None, color='olive', label="Semana 4")
plt.legend(loc="upper left")
plt.xticks(fontsize=21)
plt.yticks(fontsize=21)
plt.legend(fontsize=21)
plt.savefig('./images/sazonalidade_semanas.pdf')
plt.show()

# plt.figure(figsize=(15,5))
# plt.xlabel('Hour')
# plt.ylabel('Count')
# plt.title("Bus Line Evaluation")
# sns.lineplot(x='hora', y='validations_per_hour', data=data_2015[data_2015.d_mes == 1].groupby([ 'hora']).sum().reset_index(), ci=None, color='brown', label=f"Day 1 of month")
# for i in range(2, 30):
#     sns.lineplot(x='hora', y='validations_per_hour', data=data_2015[data_2015.d_mes == i].groupby([ 'hora']).sum().reset_index(), ci=None, color='orange', label=f"Day {i} of month")
# sns.lineplot(x='hora', y='validations_per_hour', data=data_2015[data_2015.d_mes == 30].groupby([ 'hora']).sum().reset_index(), ci=None, color='olive', label=f"Day 30 of month")
# sns.lineplot(x='hora', y='validations_per_hour', data=data_2015[data_2015.d_mes == 31].groupby([ 'hora']).sum().reset_index(), ci=None, color='salmon', label=f"Day 31 of month")
# plt.xticks(fontsize=21)
# plt.yticks(fontsize=21)
# plt.legend(fontsize=32)
# plt.legend(loc="upper left")
# plt.show()

# %%
plt.rc('axes', linewidth=2, labelpad=5)
plt.rc('text', usetex=True)
plt.rc('font', family='serif', serif='Computer Modern', size=42)
sns.set(font_scale = 2)
sns.set_theme(style="whitegrid")
plt.rc('axes', linewidth=2, labelpad=5)
plt.figure(figsize=(15,7))

ax = sns.barplot(x='d_mes', y='validations_per_hour', data=data_2015[data_2015.mes == 2].loc[data_2015.d_semana.isin([0, 1, 2, 3])].groupby([ 'd_mes']).sum().reset_index(), ci=None, color='seagreen')
ax.set(xlabel='Dia da semana (Seg / Ter / Qua / Quin)', ylabel='Count de Validacoes')
for bar in ax.patches:
    if bar.get_x() == 9.6 or bar.get_x() == 8.6:
        bar.set_color('red')
    if bar.get_x() == 7.6:
        bar.set_color('lime')
plt.xlabel('Dias do mês', fontsize=21)
plt.ylabel('Count de embarques', fontsize=21)
plt.title("Carnaval de 2015", fontsize=21)
plt.xticks(fontsize=21)
plt.yticks(fontsize=21)
plt.legend(fontsize=32)
plt.savefig('./images/fevereiro_carnaval.pdf')

plt.legend(loc="upper left")
plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
plt.rc('axes', linewidth=2, labelpad=5)
plt.rc('text', usetex=True)
plt.rc('font', family='serif', serif='Computer Modern', size=42)
sns.set(font_scale = 2)
sns.set_theme(style="whitegrid")
plt.rc('axes', linewidth=2, labelpad=5)
plt.figure(figsize=(15,7))
sns.lineplot(x='hora', y='validations_per_hour', data=data_2015[data_2015.mes == 6].groupby([ 'hora']).sum().reset_index(), ci=None, color='black', label=f"Junho")
sns.lineplot(x='hora', y='validations_per_hour', data=data_2015[data_2015.mes == 7].groupby([ 'hora']).sum().reset_index(), ci=None, color='orange', label=f"Julho")
plt.xlabel('Hora', fontsize=21)
plt.ylabel('Count de embarques', fontsize=21)
plt.title("Junho x Julho - 2018", fontsize=21)
plt.legend(loc="upper left")
plt.xticks(fontsize=21)
plt.yticks(fontsize=21)
plt.legend(fontsize=21)
plt.savefig('./images/2018/junho_julho_2018_comp.pdf')
plt.show()

# %%
plt.rc('axes', linewidth=2, labelpad=5)
plt.rc('text', usetex=True)
plt.rc('font', family='serif', serif='Computer Modern', size=42)
sns.set(font_scale = 2)
sns.set_theme(style="whitegrid")
plt.rc('axes', linewidth=2, labelpad=5)
plt.figure(figsize=(15,7))
sns.lineplot(x='hora', y='validations_per_hour', data=data_2015.groupby([ 'hora']).sum().reset_index(), ci=None, color='black')
plt.xlabel('Hora', fontsize=21)
plt.ylabel('Count de embarques', fontsize=21)
plt.title("Somatório de embarques em 2015, por hora", fontsize=21)
plt.legend(loc="upper left")
plt.xticks(fontsize=21)
plt.yticks(fontsize=21)
plt.legend(fontsize=21)
plt.savefig('./images/2015_completo_porhora.pdf')
plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
